# %%
import pandas as pd
import numpy as np
from time import sleep
import re
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from functools import reduce
import requests
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
banks = pd.read_csv('./data/banks.csv', names=['class','sentence', 'likes', 'sentiment_percentage', 'sentiment_class', 'post_id'])
post_tags = pd.read_csv('./data/post_tags.csv', names=['id','classes'])

# %%
banks.describe(include='all')
# Out:
#         class sentence        likes  sentiment_percentage  sentiment_class  \
# count    1319     1309  1319.000000           1319.000000      1319.000000
# unique     12      891          NaN                   NaN              NaN
# top     Súťaž        A          NaN                   NaN              NaN
# freq      868       92          NaN                   NaN              NaN
# mean      NaN      NaN     0.328279              0.483208         1.459439
# std       NaN      NaN     1.650598              0.140258         1.186539
# min       NaN      NaN     0.000000              0.001500         0.000000
# 25%       NaN      NaN     0.000000              0.469950         0.000000
# 50%       NaN      NaN     0.000000              0.500000         2.000000
# 75%       NaN      NaN     0.000000              0.500000         2.000000
# max       NaN      NaN    37.000000              0.969100         3.000000
#
#              post_id
# count    1319.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean    51282.990144
# std       105.832300
# min     51071.000000
# 25%     51280.000000
# 50%     51280.000000
# 75%     51280.000000
# max     51617.000000

# %%
banks.unique()
# Out:
# array([2, 3, 1, 0])

# %%
banks.head()
# Out:
#                   class                                           sentence  \
# 0  Problémy s produktov             Dávid Turcmanovič presne ani mne nejde
# 1  Problémy s produktov  kedy sa bude dať zasa prihlasovať na Samsung N...
# 2              Odpovede  Dobrý večer prajeme Štefan, veľmi nás mrzí dis...
# 3  Problémy s produktov  Marek Mitter veď to fungovalo, len po tom prob...
# 4  Problémy s produktov  Peter Madleňák mozno vtedy, ked prejdu na gpay...
#
#    likes  sentiment_percentage  sentiment_class  post_id
# 0      0                0.1888                2    51453
# 1      1                0.4092                2    51514
# 2      0                0.2985                2    51514
# 3      1                0.2437                2    51514
# 4      2                0.3591                2    51514

# %%
banks['class'].unique()
# Out:
# array(['Problémy s produktov', 'Odpovede', 'Interakcia', 'Neutral',
#        'Produkt', 'Otázky', 'Ponuka produktov',
#        'Cena produktov / benefity', 'Ostatné', 'Súťaž', 'Pobočka',
#        'Problémy s produktom'], dtype=object)

# %%
no_nulls_banks = banks[ ~(banks.isnull().sentence == True)].drop_duplicates('sentence')
no_nulls_banks.describe(include="all")
# Out:
#         class             sentence       likes  sentiment_percentage  \
# count     891                  891  891.000000            891.000000
# unique     12                  891         NaN                   NaN
# top     Súťaž  Každý môže byť aleB         NaN                   NaN
# freq      450                    1         NaN                   NaN
# mean      NaN                  NaN    0.484848              0.472460
# std       NaN                  NaN    1.989451              0.167136
# min       NaN                  NaN    0.000000              0.001500
# 25%       NaN                  NaN    0.000000              0.397700
# 50%       NaN                  NaN    0.000000              0.492200
# 75%       NaN                  NaN    0.000000              0.533300
# max       NaN                  NaN   37.000000              0.969100
#
#         sentiment_class       post_id
# count        891.000000    891.000000
# unique              NaN           NaN
# top                 NaN           NaN
# freq                NaN           NaN
# mean           2.056117  51285.900112
# std            0.873579    127.547339
# min            0.000000  51071.000000
# 25%            2.000000  51280.000000
# 50%            2.000000  51280.000000
# 75%            3.000000  51354.000000
# max            3.000000  51617.000000

# %%
no_nulls_banks['class']  = no_nulls_banks['class'].apply(lambda x: x if x != 'Problémy s produktov' else 'Problémy s produktom')

# %%
no_nulls_banks['class'].value_counts()
# Out:
# Súťaž                        450
# Problémy s produktom          93
# Odpovede                      82
# Neutral                       72
# Ponuka produktov              61
# Interakcia                    47
# Cena produktov / benefity     29
# Produkt                       26
# Otázky                        20
# Ostatné                        7
# Pobočka                        4
# Name: class, dtype: int64

# %%
[*no_nulls_banks[no_nulls_banks['class'] == 'Pobočka'].head(30).sentence]
# Out:
# ['Tatra banka v modernizovanej pobocke v HM Tesco Zilina mate parfum ktory akoze rozvoniava vzduch je to vsak priserny smrad a Vas personal tvrdi ze je to vona banky rovnaky smrad vsak pouzivaju aj v predajniach CCC Obuvi kde nedokazem nakupovat realita je taka ze ani na Vasu pobocku nemozem chodit nakolko nedokazem vydrzat tu vonu banky',
#  'Ved v leviciach je pobocka tatra banky zrusena a ani bankomat tam neni',
#  'Nechválí sa Tatra banka tým, že je najviac digitálna? Tak načo investovať do redizajnu pobočiek keď väčšina z vašich klientov, podľa vás, používa iba appku? A dokonca aj hypotéku si človek cez ňu bude moct založit :-).',
#  'Všade čierna ako smútok v pohrebnictve..']

# %%
joined_products = no_nulls_banks.copy(deep=True)
product_classes = ['Produkt','Ponuka produktov', 'Cena produktov / benefity', 'Problémy s produktom']
joined_products['class'] = joined_products['class'].apply(lambda x: x if x not in product_classes else 'Produkt')
joined_products.head()
# Out:
#       class                                           sentence  likes  \
# 0   Produkt             Dávid Turcmanovič presne ani mne nejde      0
# 1   Produkt  kedy sa bude dať zasa prihlasovať na Samsung N...      1
# 2  Odpovede  Dobrý večer prajeme Štefan, veľmi nás mrzí dis...      0
# 3   Produkt  Marek Mitter veď to fungovalo, len po tom prob...      1
# 4   Produkt  Peter Madleňák mozno vtedy, ked prejdu na gpay...      2
#
#    sentiment_percentage  sentiment_class  post_id
# 0                0.1888                2    51453
# 1                0.4092                2    51514
# 2                0.2985                2    51514
# 3                0.2437                2    51514
# 4                0.3591                2    51514

# %%
joined_products['class'].value_counts().plot(kind='bar')

# %%
product_on_post_id = (joined_products['class'] == 'Produkt') & (joined_products['post_id'] == 51453)
joined_products[product_on_post_id]
# Out:
#         class                                           sentence  likes  \
# 0     Produkt             Dávid Turcmanovič presne ani mne nejde      0
# 73    Produkt  Tatra banka teda to máme chápať tak, že sa nec...      0
# 1296  Produkt  Mobilné platby dlhodobo nefungujú na androide 10!      1
# 1297  Produkt   Guy Landry Kindji tiez by som bol za pridanie MC      1
# 1298  Produkt         Mohli by ste radšej sprístupniť GARMIN PAY      0
# 1300  Produkt  To je fajn ale zišlo by sa to aj oficiálne vys...      0
# 1303  Produkt  Najväčšia sranda bola že týždeň sa vedelo o ch...      0
# 1308  Produkt  Od poslednej aktualizacie platba Mobil Pay nef...      0
# 1309  Produkt  Ako fakt zadať všetky údaje pre identifikáciu ...      1
# 1310  Produkt            Keby tak tie platby funkovali všakže...      1
# 1314  Produkt                            Čo je s MC a Apple Pay?      0
# 1316  Produkt  Keby ste radšej povolili Google pay a zahodili...      2
# 1318  Produkt  Guy Landry Kindji Pretože chcú, aby sme použív...      1
#
#       sentiment_percentage  sentiment_class  post_id
# 0                   0.1888                2    51453
# 73                  0.4989                2    51453
# 1296                0.2861                2    51453
# 1297                0.5133                3    51453
# 1298                0.4081                2    51453
# 1300                0.3011                2    51453
# 1303                0.0791                2    51453
# 1308                0.2597                2    51453
# 1309                0.4805                2    51453
# 1310                0.4716                2    51453
# 1314                0.4590                2    51453
# 1316                0.2639                2    51453
# 1318                0.4892                2    51453

# %%
joined_products[['class', 'post_id']].corr()
# Out:
#          post_id
# post_id      1.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(joined_products['class'].unique())
le.classes_
# Out:
# array(['Interakcia', 'Neutral', 'Odpovede', 'Ostatné', 'Otázky',
#        'Pobočka', 'Produkt', 'Súťaž'], dtype=object)

# %%
encoded_classes = joined_products.copy(deep=True)
encoded_classes['class'] = le.transform(encoded_classes['class'])
encoded_classes.head()
# Out:
#    class                                           sentence  likes  \
# 0      6             Dávid Turcmanovič presne ani mne nejde      0
# 1      6  kedy sa bude dať zasa prihlasovať na Samsung N...      1
# 2      2  Dobrý večer prajeme Štefan, veľmi nás mrzí dis...      0
# 3      6  Marek Mitter veď to fungovalo, len po tom prob...      1
# 4      6  Peter Madleňák mozno vtedy, ked prejdu na gpay...      2
#
#    sentiment_percentage  sentiment_class  post_id
# 0                0.1888                2    51453
# 1                0.4092                2    51514
# 2                0.2985                2    51514
# 3                0.2437                2    51514
# 4                0.3591                2    51514

# %%
encoded_classes[['class', 'post_id']].corr()
# Out:
#             class   post_id
# class    1.000000 -0.147811
# post_id -0.147811  1.000000

# %%
encoded_classes['post_id'].unique()
# Out:
# array([51453, 51514, 51589, 51617, 51239, 51097, 51280, 51073, 51074,
#        51076, 51092, 51094, 51095, 51096, 51170, 51071, 51147, 51278,
#        51354, 51400, 51402, 51401])

# %%
joined_products[joined_products['post_id'] == 51453][['class', 'sentence']]
# Out:
#          class                                           sentence
# 0      Produkt             Dávid Turcmanovič presne ani mne nejde
# 72    Odpovede  Dobrý deň Marek, veľmi nás mrzí diskomfort, kt...
# 73     Produkt  Tatra banka teda to máme chápať tak, že sa nec...
# 74     Neutral                           Ján Gilan  aj nabudúce 😂
# 1294  Odpovede  Dobrý deň Guy, aktuálne podporu pre Mastecard ...
# 1295    Otázky                              Aky mate na to dovod?
# 1296   Produkt  Mobilné platby dlhodobo nefungujú na androide 10!
# 1297   Produkt   Guy Landry Kindji tiez by som bol za pridanie MC
# 1298   Produkt         Mohli by ste radšej sprístupniť GARMIN PAY
# 1299   Neutral  Guy Landry Kindji $$ samozrejme, aky iny mozu ...
# 1300   Produkt  To je fajn ale zišlo by sa to aj oficiálne vys...
# 1303   Produkt  Najväčšia sranda bola že týždeň sa vedelo o ch...
# 1308   Produkt  Od poslednej aktualizacie platba Mobil Pay nef...
# 1309   Produkt  Ako fakt zadať všetky údaje pre identifikáciu ...
# 1310   Produkt            Keby tak tie platby funkovali všakže...
# 1311   Neutral  Chcem Samsung Pay - bezpečnosť a efektivita le...
# 1312   Neutral                          Michal Trulík dik za radu
# 1313  Odpovede  Dobrý deň, Jan, ako sme už viackrát spomínali,...
# 1314   Produkt                            Čo je s MC a Apple Pay?
# 1315   Neutral              Ján Gilan kúp si iPhone a máš pokoj 😂
# 1316   Produkt  Keby ste radšej povolili Google pay a zahodili...
# 1317  Odpovede  Dušan, veľmi nás mrzí diskomfort, ktorý niekto...
# 1318   Produkt  Guy Landry Kindji Pretože chcú, aby sme použív...

# %%
def get_train_test( df ):
    x_trains, x_tests,  y_trains, y_tests = [], [], [], []
    for tag in df['class'].unique().tolist():
        x, y = df[df['class'] == tag].drop(columns=['class']), df[df['class'] == tag]['class']
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=1000)
        x_trains.append(x_train)
        x_tests.append(x_test)    
        y_trains.append(y_train)    
        y_tests.append(y_test)   

    return  pd.concat(x_trains), pd.concat(x_tests), pd.concat(y_trains), pd.concat(y_tests)

x_train, x_test, y_train, y_test = get_train_test(joined_products) 
pd.merge(x_train, y_train, left_index=True, right_index=True)['class'].value_counts().plot(kind='bar')
# Out:
# Index(['sentence', 'likes', 'sentiment_percentage', 'sentiment_class',
#        'post_id'],
#       dtype='object')

# %%
joined_products[joined_products['class'] == 'Neutral'][['sentence','sentiment_class']]
# Out:
#                                                sentence  sentiment_class
# 11    Chválim zmenu... ešte keby sa dalo nastaviť, ž...                2
# 22    Stará verzia na mňa pôsobila prehľadnejšie. No...                2
# 36    Tak vďaka za stanovisko. Dúfam, že sa čoskoro ...                3
# 42    Tomáš Starý keď nechcete kampane na úvery a po...                2
# 44               Luboš Slezák predpotopnej? 😂😂😂😂 Okej 😄                2
# 46            Luboš Slezák nechcete platit myslienkami😁                2
# 47                     Gabriela Molnar staci mi gpay. 🙂                2
# 49                 Michal Maco Molnár nie. Ta je super.                3
# 51                                             ABN AMRO                1
# 52                Peter je to tam ING take clues thanks                3
# 64                     Tatra banka len pekne recicky!!!                3
# 74                             Ján Gilan  aj nabudúce 😂                3
# 133               Tatra banka SC Europa Banska Bystrica                2
# 135                      Michal Bodnár rusia sa pobocky                2
# 139   Tatra banka zrusit nie ale zredukovat pobocky ...                2
# 141                              Ruky hore, peňeži sem!                3
# 166   Nejake to je tmave, nic moc, mohlo to byt lepsie.                2
# 173                             Andrea Benkeová dakujem                3
# 178   Peter Minárik  bolo to cez tyzden. Presne aj j...                2
# 196         Pri minutej 1000-ke je to už 20 EUR rozdiel                2
# 209          Tatra banka Škoda. Možno raz sa dočkáme :)                3
# 210   Revolut - Mastercard | 14 339 Ft / 42,98 € = K...                2
# 212   100 € x 333,62 = 33 362 Ft\n100 € x 335,13 = 3...                2
# 250   Peter Maj to preto ze si uvedomuju vysledky in...                3
# 265               Dušan, treba vidieť na vlastné oči :)                2
# 270   VÚB banka ďakujem za odpoveď takže budeme čaka...                2
# 287   https://gm.ifortuna.sk/nahlad-tiketu?ticket_id...                2
# 310                                                 155                0
# 1043             Tak zmente banku. Je ich malo na trhu?                2
# 1044                     Tomáš Zausin  Už to rieším !!!                2
# ...                                                 ...              ...
# 1200  Jakub Horvath ja som problem s platenim s Visa...                2
# 1207                                      sak to tam je                2
# 1212  Denis Baška v takom nemecku nemáte zadarmo pom...                2
# 1216                               Dominik Kovács kde ?                1
# 1218  v obchod play otvor apku tatra banka a niekde ...                2
# 1220  Viktor Ivasuk zabudli dodať že to prajú veselé...                3
# 1224                            Marek MGo Mi8 NFC má...                1
# 1225                  Juraj Krajčík Lite verzia nie ;-)                3
# 1226  Silvia Aksagav  dobry den. wallet (penazenka) ...                3
# 1230  Peter Šuranský, ale da. Minuly tyzden som tak ...                2
# 1233  Róbert Šrotýř nápodobne skúšam to inou bankou ...                3
# 1239  Nemám NFC v mobile (Xiaomi Mi8) ani smart hodi...                3
# 1244  Pbl A Zdenka neplatis ucty,faktury  ? semtam n...                2
# 1246  Jakub Horvath ale ja osobne som nemala vobec p...                2
# 1247  skvele. Tesim sa ze ste aspon niekomu dali uve...                3
# 1250            Marek MGo anj nevieš aký máš telefón. 😁                2
# 1252  Lukáš Lucky viem len som to nevypisoval celé v...                3
# 1253            A tatra banka ma 49 000 zamestnancov :)                3
# 1259  Pbl A Zdenka tak si založte účet v Tatrabanke ...                2
# 1260  Áno kopa výberov mobilov áno hlavne preto ze z...                2
# 1266  Tatra banka OK skusim to s business poradcom s...                2
# 1280  Sim Sala Bim je to v pláne, ale do konca roka ...                2
# 1281  Jozef Fischo Fischer  vela veci je iba v plane...                3
# 1282                                    Sim Sala Bim jj                2
# 1292  tak riešim to už po svojom, ale iným možno pom...                3
# 1299  Guy Landry Kindji $$ samozrejme, aky iny mozu ...                3
# 1305  Dávid Zimovčák aktuálne tiež skúšam 365.bank a...                3
# 1311  Chcem Samsung Pay - bezpečnosť a efektivita le...                2
# 1312                          Michal Trulík dik za radu                2
# 1315              Ján Gilan kúp si iPhone a máš pokoj 😂                2
#
# [72 rows x 2 columns]

# %%
joined_products['class'].value_counts()
# Out:
# Súťaž         450
# Produkt       209
# Odpovede       82
# Neutral        72
# Interakcia     47
# Otázky         20
# Ostatné         7
# Pobočka         4
# Name: class, dtype: int64

# %%
other_banks = joined_products.copy(deep=True)
other_banks['class'] = joined_products['class'].apply(lambda x: x if x in ['Produkt', 'Súťaž'] else 'Ine')

# %%
other_banks['class'].value_counts().plot(kind='bar')

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
        
    
    
neural_network = MLPClassifier(hidden_layer_sizes=(50,), max_iter=100, alpha=1e-4,
                                   solver='sgd', verbose=10, tol=1e-4, random_state=1,
                                   learning_rate_init=.1)
classifier1 = LogisticRegression(solver='lbfgs')
classifier2 = GaussianNB()
classifier3 = MultinomialNB()
classifier4 = SGDClassifier()
vectorizer = CountVectorizer()
random_forest = RandomForestClassifier(n_estimators=100, max_depth=60,random_state=42)
support_vector_machine = svm.SVC(gamma='scale')

# df = pd.read_csv('./data/labeled_comments.csv', names=['sentence', 'class'])

def transform_comments( df, vectorizer ):
    df = df[ ~(df.isnull().sentence == True)].drop_duplicates('sentence')
    x_train, x_test, y_train, y_test = get_train_test(df) 
    vectorizer.fit(x_train)
    x_train = vectorizer.transform(x_train)
    x_test  = vectorizer.transform(x_test)
    return x_train, x_test, y_train, y_test
    
def train_classifier( x_train, x_test, y_train, y_test, classifier):
    classifier.fit(x_train.toarray(), y_train)
    y_pred = classifier.predict(x_test.toarray())
    scoring = {
        "f1_score":f1_score(y_pred, y_test, average='macro'),
        "recall_score": recall_score(y_pred, y_test, average='macro'),
        "precision_score": precision_score(y_pred, y_test, average='macro'),
        "accuracy_score": accuracy_score(y_pred,y_test)
    }
    return classifier, scoring

def predict( model , messages, vectorizer):
    message_series = pd.Series(messages)
    return model.predict(vectorizer.transform(message_series))

# %%
x_train, x_test, y_train, y_test  = transform_comments(other_banks, vectorizer)
x_train
# Out:
# <5x5 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5 stored elements in Compressed Sparse Row format>

# %%
model, score = train_classifier( *transform_comments(other_banks, vectorizer),neural_network)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-175-c8ff5be147d4> in <module>
# ----> 1 model, score = train_classifier( *transform_comments(other_banks, vectorizer),neural_network)
#
# <ipython-input-173-a7daa0e5352d> in train_classifier(x_train, x_test, y_train, y_test, classifier)
#      38
#      39 def train_classifier( x_train, x_test, y_train, y_test, classifier):
# ---> 40     classifier.fit(x_train.toarray(), y_train)
#      41     y_pred = classifier.predict(x_test.toarray())
#      42     scoring = {
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py in fit(self, X, y)
#     980         """
#     981         return self._fit(X, y, incremental=(self.warm_start and
# --> 982                                             hasattr(self, "classes_")))
#     983
#     984     @property
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py in _fit(self, X, y, incremental)
#     321                              hidden_layer_sizes)
#     322
# --> 323         X, y = self._validate_input(X, y, incremental)
#     324         n_samples, n_features = X.shape
#     325
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py in _validate_input(self, X, y, incremental)
#     917     def _validate_input(self, X, y, incremental):
#     918         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 919                          multi_output=True)
#     920         if y.ndim == 2 and y.shape[1] == 1:
#     921             y = column_or_1d(y, warn=True)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     727         y = y.astype(np.float64)
#     728
# --> 729     check_consistent_length(X, y)
#     730
#     731     return X, y
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [5, 756]

# %%
score
# Out:
# {'f1_score': 0.22331691297208536,
#  'recall_score': 0.1679012345679012,
#  'precision_score': 0.3333333333333333,
#  'accuracy_score': 0.5037037037037037}

# %% [markdown]
# model.predict(vectorizer.transform().toarray())
# daco = pd.Series(['A B C', 'Prislo mi to celkom lacne'])

# %%
model.predict(vectorizer.transform(daco))
# Out:
# array([7, 6])

# %%
predict(model, ['predajna je spina'], vectorizer)
# Out:
# array(['Súťaž'], dtype='<U7')

# %%
help(recontruct_sentence)
# Out:
# Help on function recontruct_sentence in module __main__:
#
# recontruct_sentence(sentence)

# %%
recontruct_sentence(df.iloc[1].sentence, 1)
# Out:
# [{'word': 'PEPCO', 'meta': '{S}', 'word_orig': 'PEPCO'},
#  {'word': 'Slovensko', 'word_orig': 'Slovensko'},
#  {'word': 'no', 'word_orig': 'no'},
#  {'word': 'len', 'word_orig': 'len'},
#  {'word': 'tie', 'word_orig': 'tie'},
#  {'word': 'tašky', 'word_orig': 'tašky'},
#  {'word': 'v', 'word_orig': 'v'},
#  {'word': 'dnešnej', 'word_orig': 'dnešnej'},
#  {'word': 'dobe', 'word_orig': 'dobe'},
#  {'word': 'nič', 'word_orig': 'nič'},
#  {'word': 'nevydržia', 'word_orig': 'nevydržia'},
#  {'word': 'zipsy', 'word_orig': 'zipsy'},
#  {'word': 'traky', 'word_orig': 'traky'},
#  {'word': '.', 'meta': '{/S}', 'word_orig': '.'},
#  {'word': '.', 'meta': '{S}', 'word_orig': '.'},
#  {'word': '.', 'meta': '{/S}', 'word_orig': '.'},
#  {'word': '.', 'meta': '{S}', 'word_orig': '.'},
#  {'word': '😘', 'meta': '{S}', 'word_orig': '😘'}]

# %% [markdown]
# # Preprocessing data and storing it in mongodb

# %%
def recontruct_sentence(sentence, dll):
    params = {
        "text": sentence,
        "apikey": "DEMO",
        "textrestorer": "ProbabilisticDiacriticRestorer",
    }
    headers = {
        'content-type': 'application/x-www-form-urlencoded',
        'Accept': 'application/json'
    }
    response = requests.post("http://arl6.library.sk/nlp4sk/api", data=params)
    sleep(dll)
    return reduce(lambda acc, x: acc + ' ' + x['word'], response.json(), '')

# %%
def preprocess_sentence(sentence, dll):
    params = {
        "text": sentence,
        "apikey": "DEMO",
        "lemmatizer": "ProbabilisticLemmatizer",
        "postagger": "ProbabilisticPOSTagger",
        "tokenizer": "SmartRuleTokenizer"
    }
    headers = {
        'content-type': 'application/x-www-form-urlencoded',
        'Accept': 'application/json'
    }
    response = requests.post("http://arl6.library.sk/nlp4sk/api", data=params)
    sleep(dll)
    return response.json()

# %%
def only_allowed_pos(x):
    try:
        return True if x['pos'][0] in ['D', 'A', 'S'] else False
    except:
        return False
    
def filter_allowed_pos(comment):
    return list(filter(only_allowed_pos,comment))

# %%
def tranform( x ):
    try:
        sentence = recontruct_sentence(x['sentence'], 5)
        comment = preprocess_sentence(sentence, 5)
        return {
            'sentence':sentence,
            'class': x['class'],
            'processed': comment
        }
    except:
        print('error')
        return None

# %%
df = pd.read_csv('./data/banks.csv', names=['class','sentence', 'likes', 'sentiment_percentage', 'sentiment_class'])
df = df[ ~(df.isnull().sentence == True)].drop_duplicates('sentence')

# %%
df
# Out:
#                      class                                           sentence  \
# 0                  Neutral                                                155
# 2                    Súťaž                              Vsetci tak ze A B C D
# 3                    Súťaž                                Všetci 😃 inak typ B
# 4                    Súťaž                            A, B, C, D takže všetci
# 5                    Súťaž                           C aj keď každý investuje
# 6                    Súťaž      sutazim o krasnu vyhru  žeby vsetci ? A,B,C,D
# 7                    Súťaž                Investor VÚB je C s veľkým úsmevom.
# 8                    Súťaž               Všetci môžu byť investormi vo VÚB...
# 9                    Súťaž  Každý snich môže byť investor vúb banky tipujem C
# 10                   Súťaž  Investor neviem ale každý z nich je určite pla...
# 11                   Súťaž  Každý môže byť ale najviac sa mi hodí D- príje...
# 12                   Súťaž  Investormi sú, podľa mňa, všetci štyria A B C ...
# 13                   Súťaž     Každý môže byť investor,z obrázku sa mi páči C
# 14                   Súťaž  Investorom sú všetci. Ak majú kúpenú nehnuteľn...
# 15                   Súťaž  Pánovi pod D sa to veľmi nevyplatí ale ABC môž...
# 16                   Súťaž  Tak keďže to môže byť ktokoľvek tak si myslím,...
# 17                   Súťaž  D, ten už v jeho veku možno aj ma čo investova...
# 18                   Súťaž  Bez rozdielov, kazdy kto ma kapital ktory inve...
# 19                   Súťaž     Investor môže byť každý tzn. A aj B aj C aj D.
# 20                   Súťaž        A,b,c,d. Kazdy investoval do niecoho ineho.
# 21                   Súťaž  Každý je investorom ale najviac podľa mňa by t...
# 22                   Súťaž  A, B, C, D investor je každý, či už má hypoték...
# 23                   Súťaž                         Každý jeden z nich.... 👍👍👍
# 24                   Súťaž                Všetci môžu byt s VÚB investormi!!!
# 25                   Súťaž             Všetci štyria, vek nie je prekážkou :)
# 26                   Súťaž                  Investormi sú všetci na obrázku ☺
# 27                   Súťaž                     Vsetci styria - A, B, C aj D 😎
# 28                   Súťaž         Investormi mozu byt vsetci ale tipnem si N
# 29                   Súťaž  Ja si myslím že pani pod písmenom A ..\nAle bu...
# 30                   Súťaž                          Každý môže byť investor 😉
# ...                    ...                                                ...
# 1290      Ponuka produktov  Presne tak. Načo je mi taká banka keď nevedia ...
# 1291      Ponuka produktov  Jaaj tak Google Pay hej? A Apple Pay nebude? C...
# 1292      Ponuka produktov                             Už dávno malo byť 🍎Pay
# 1293      Ponuka produktov         Apple pay bude cca s prichodom iPhone 15 ?
# 1294      Ponuka produktov                    Davajte uz konecne Apple Pay!!!
# 1295  Problémy s produktom  VÚB banka dobrý deň, opäť mám ten istý problém...
# 1296      Ponuka produktov                            presne si to vystihol 👍
# 1297              Odpovede  Marián Zuzana Lapoš Pekny den. Od jari sme mal...
# 1298      Ponuka produktov  Ste jedna z posledných bank na Slovensku ktorá...
# 1299  Problémy s produktom  Bohumil Bobo Valent presne tak ako vravíš. S m...
# 1300  Problémy s produktom  No ja som tento rok riešila platbu dovolenky, ...
# 1301      Ponuka produktov              Tommy Cé tiez sa radujes z cashbacku?
# 1302      Ponuka produktov                                   Stano Kuruc amen
# 1303      Ponuka produktov  Stano Kuruc Pekny den. Postup nasadzovania bol...
# 1304      Ponuka produktov  Roman, myslim si, ze v dnesnom svete, kedy sa ...
# 1305      Ponuka produktov  ešte aj na ticket restaurant kartu mi to fungu...
# 1306  Problémy s produktom  dnes rovnaky problem, ani cez mobilbanking, an...
# 1307      Ponuka produktov  Podobne, taktiež mi bolo povedané, že najneskô...
# 1308  Problémy s produktom  Presne tak, mám rovnaký problém, ani e-platby ...
# 1309  Problémy s produktom  VÚB banka Rovnaky problem, neda sa nikde prihl...
# 1310      Ponuka produktov  Pridavam sa k ostatnym komentujucim - Apple Pa...
# 1311  Problémy s produktom  Nuz, uz pre istotu ani reakciu nedostaneme. Ra...
# 1312      Ponuka produktov  Za Apple Pay sa tu hádate :) ľudia doteraz bez...
# 1313      Ponuka produktov  Cakanie na  pay od VUB si sprijemnujem s Revo...
# 1314  Problémy s produktom  Rád by som vedel, prečo si nemôžeme ľubovoľne ...
# 1315      Ponuka produktov  VÚB banka dosť zvláštne čo hovoríte nakoľko vo...
# 1316  Problémy s produktom  Ehmm na tento Vas novy typ kodovania do intern...
# 1317  Problémy s produktom  Erika Fúsková Mne to urobiť nechceli. Neriešim...
# 1318      Ponuka produktov  Mrzi ma, ze moja oblubena banka na SK si nedok...
# 1319                 Súťaž                               Každý z nich ABCD :)
#
#       likes  sentiment_percentage  sentiment_class
# 0         0                0.5000                0
# 2         0                0.5000                0
# 3         0                0.6240                3
# 4         0                0.5000                0
# 5         0                0.4986                2
# 6         0                0.7843                3
# 7         0                0.3979                2
# 8         0                0.4731                2
# 9         0                0.3741                2
# 10        0                0.3113                2
# 11        0                0.4482                2
# 12        0                0.7756                3
# 13        0                0.8176                3
# 14        0                0.1459                2
# 15        0                0.4741                2
# 16        0                0.4163                2
# 17        0                0.5493                3
# 18        0                0.4872                2
# 19        0                0.4869                2
# 20        0                0.5009                3
# 21        0                0.4869                2
# 22        1                0.1367                2
# 23        0                0.5797                3
# 24        0                0.4731                2
# 25        0                0.5654                3
# 26        0                0.5252                3
# 27        0                0.4163                2
# 28        0                0.4869                2
# 29        0                0.6722                3
# 30        0                0.5203                3
# ...     ...                   ...              ...
# 1290     37                0.4010                2
# 1291      5                0.0906                2
# 1292      2                0.3616                2
# 1293      5                0.4583                2
# 1294      3                0.5225                3
# 1295      1                0.1623                2
# 1296      7                0.6607                3
# 1297      3                0.0315                2
# 1298     13                0.2645                2
# 1299      0                0.3898                2
# 1300      1                0.4803                2
# 1301      0                0.5000                1
# 1302      0                0.5000                1
# 1303      0                0.2261                2
# 1304      1                0.0187                2
# 1305      2                0.4268                2
# 1306      0                0.4480                2
# 1307      1                0.3177                2
# 1308      0                0.2026                2
# 1309      0                0.3031                2
# 1310      5                0.2548                2
# 1311      0                0.1198                2
# 1312      4                0.4004                2
# 1313      2                0.5714                3
# 1314      2                0.0015                2
# 1315      3                0.1985                2
# 1316      2                0.2127                2
# 1317      1                0.2250                2
# 1318      7                0.2854                2
# 1319      0                0.6388                3
#
# [892 rows x 5 columns]

# %%
coms = (df.iloc[0:1]).apply(tranform, axis=1)

# %%
[*coms]
# Out:
# [{'sentence': ' To čo bude za kvalita to vydrží asi týždeň ten vak',
#   'class': 'Quality',
#   'processed': [{'word': 'To', 'meta': '{S}', 'pos': [], 'lemma': ['to']},
#    {'word': 'čo', 'pos': ['P'], 'lemma': ['čo']},
#    {'word': 'bude', 'pos': ['V'], 'lemma': ['byť']},
#    {'word': 'za', 'pos': ['E'], 'lemma': ['za']},
#    {'word': 'kvalita', 'pos': ['S'], 'lemma': ['kvalita']},
#    {'word': 'to', 'pos': [], 'lemma': ['to']},
#    {'word': 'vydrží', 'pos': ['V'], 'lemma': ['vydržať']},
#    {'word': 'asi', 'pos': [], 'lemma': ['asi']},
#    {'word': 'týždeň', 'pos': ['S'], 'lemma': ['týždeň']},
#    {'word': 'ten', 'pos': ['P'], 'lemma': ['ten']},
#    {'word': 'vak', 'pos': ['S'], 'lemma': ['vak']}]}]

# %%
# ! pip3.7 install --upgrade pymongo dnspython
import pymongo
client = pymongo.MongoClient("mongodb+srv://adamstuller:Mit29kis@cluster0-rnyqh.mongodb.net/test?retryWrites=true&w=majority")
db = client.bpdb

# %%
db['comments'].insert_one(comment)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-d58cc725d43d> in <module>
# ----> 1 db['comments'].insert_one(comment)
#
# NameError: name 'comment' is not defined

# %%
db['comments'].insert_many([*coms])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-59277eff81e1> in <module>
# ----> 1 db['comments'].insert_many([*coms])
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     755         write_concern = self._write_concern_for(session)
#     756         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 757         blk.ops = [doc for doc in gen()]
#     758         blk.execute(write_concern, session=session)
#     759         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in <listcomp>(.0)
#     755         write_concern = self._write_concern_for(session)
#     756         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 757         blk.ops = [doc for doc in gen()]
#     758         blk.execute(write_concern, session=session)
#     759         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in gen()
#     746             """A generator that validates documents and handles _ids."""
#     747             for document in documents:
# --> 748                 common.validate_is_document_type("document", document)
#     749                 if not isinstance(document, RawBSONDocument):
#     750                     if "_id" not in document:
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/common.py in validate_is_document_type(option, value)
#     481                         "bson.raw_bson.RawBSONDocument, or "
#     482                         "a type that inherits from "
# --> 483                         "collections.MutableMapping" % (option,))
#     484
#     485
#
# TypeError: document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping

# %%
for (fr, to) in zip(range(2600, len(df) , 10), range(2610, len(df) + 10, 10)):
    coms = (df.iloc[fr:to]).apply(tranform, axis=1)
    db['comments'].insert_many([com for com in coms if com is not None])
    print(fr,to)
# Out:
# error
# 2600 2610
# error
# 2610 2620
# 2620 2630
# 2630 2640
# 2640 2650
# 2650 2660
# 2660 2670
# 2670 2680
# 2680 2690
# 2690 2700
# 2700 2710
# 2710 2720
# 2720 2730
# 2730 2740
# 2740 2750
# 2750 2760
# 2760 2770
# 2770 2780
# 2780 2790
# 2790 2800
# 2800 2810
# 2810 2820
# 2820 2830
# 2830 2840
# 2840 2850
# 2850 2860
# 2860 2870
# 2870 2880
# 2880 2890
# 2890 2900
# 2900 2910
# 2910 2920
# 2920 2930
# 2930 2940
# 2940 2950
# 2950 2960
# 2960 2970
# 2970 2980
# 2980 2990
# 2990 3000
# 3000 3010
# 3010 3020
# 3020 3030
# 3030 3040
# 3040 3050
# 3050 3060
# 3060 3070
# 3070 3080
# 3080 3090
# 3090 3100
# error
# 3100 3110
# 3110 3120
# 3120 3130
# 3130 3140
# 3140 3150
# error
# 3150 3160
# 3160 3170
# 3170 3180
# 3180 3190
# 3190 3200
# 3200 3210
# 3210 3220
# 3220 3230
# 3230 3240
# 3240 3250
# 3250 3260
# 3260 3270
# 3270 3280
# 3280 3290
# 3290 3300
# 3300 3310
# 3310 3320
# 3320 3330
# 3330 3340
# 3340 3350
# 3350 3360
# 3360 3370
# 3370 3380
# 3380 3390
# 3390 3400
# 3400 3410
# 3410 3420
# 3420 3430
# 3430 3440
# 3440 3450
# 3450 3460
# 3460 3470
# 3470 3480
# 3480 3490
# 3490 3500
# 3500 3510
# 3510 3520
# 3520 3530
# 3530 3540
# 3540 3550
# 3550 3560
# 3560 3570
# 3570 3580
# 3580 3590
# 3590 3600
# 3600 3610
# 3610 3620
# 3620 3630
# 3630 3640
# 3640 3650
# 3650 3660
# 3660 3670
# 3670 3680
# 3680 3690
# 3690 3700
# 3700 3710
# 3710 3720
# 3720 3730
# 3730 3740
# 3740 3750
# 3750 3760
# 3760 3770
# 3770 3780
# 3780 3790
# 3790 3800
# 3800 3810
# 3810 3820
# 3820 3830
# 3830 3840
# 3840 3850
# 3850 3860
# 3860 3870
# 3870 3880
# 3880 3890
# 3890 3900
# 3900 3910
# 3910 3920
# 3920 3930
# 3930 3940
# 3940 3950
# 3950 3960
# 3960 3970
# 3970 3980
# 3980 3990
# 3990 4000
# 4000 4010
# 4010 4020
# 4020 4030
# 4030 4040
# 4040 4050
# 4050 4060
# 4060 4070
# 4070 4080
# 4080 4090
# 4090 4100
# 4100 4110
# 4110 4120
# 4120 4130
# 4130 4140
# 4140 4150
# 4150 4160
# 4160 4170
# 4170 4180
# 4180 4190
# 4190 4200
# 4200 4210
# 4210 4220
# 4220 4230
# 4230 4240
# 4240 4250
# 4250 4260
# 4260 4270
# 4270 4280
# error
# 4280 4290
# 4290 4300
# 4300 4310
# 4310 4320
# 4320 4330
# 4330 4340
# 4340 4350
# 4350 4360
# 4360 4370
# 4370 4380
# 4380 4390
# 4390 4400
# 4400 4410
# 4410 4420
# 4420 4430
# 4430 4440
# 4440 4450
# 4450 4460
# 4460 4470
# 4470 4480
# 4480 4490
# 4490 4500
# 4500 4510
# 4510 4520
# error
# error
# error
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-50-04099a58c1be> in <module>
#       1 for (fr, to) in zip(range(2600, len(df) , 10), range(2610, len(df) + 10, 10)):
#       2     coms = (df.iloc[fr:to]).apply(tranform, axis=1)
# ----> 3     db['comments'].insert_many([com for com in coms if com is not None])
#       4     print(fr,to)
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     756         blk = _Bulk(self, ordered, bypass_document_validation)
#     757         blk.ops = [doc for doc in gen()]
# --> 758         blk.execute(write_concern, session=session)
#     759         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     760
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     509                 self.execute_no_results(sock_info, generator)
#     510         else:
# --> 511             return self.execute_command(generator, write_concern, session)
#     512
#     513
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     342
#     343         client = self.collection.database.client
# --> 344         with client._tmp_session(session) as s:
#     345             client._retry_with_session(
#     346                 self.is_retryable, retryable_bulk, s, self)
#
# ~/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _tmp_session(self, session, close)
#    1818             return
#    1819
# -> 1820         s = self._ensure_session(session)
#    1821         if s and close:
#    1822             with s:
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1805             # Don't make implicit sessions causally consistent. Applications
#    1806             # should always opt-in.
# -> 1807             return self.__start_session(True, causal_consistency=False)
#    1808         except (ConfigurationError, InvalidOperation):
#    1809             # Sessions not supported, or multiple users authenticated.
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1758
#    1759         # Raises ConfigurationError if sessions are not supported.
# -> 1760         server_session = self._get_server_session()
#    1761         opts = client_session.SessionOptions(**kwargs)
#    1762         return client_session.ClientSession(
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1791     def _get_server_session(self):
#    1792         """Internal: start or resume a _ServerSession."""
# -> 1793         return self._topology.get_server_session()
#    1794
#    1795     def _return_server_session(self, server_session, lock):
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/topology.py in get_server_session(self)
#     480                         readable_server_selector,
#     481                         self._settings.server_selection_timeout,
# --> 482                         None)
#     483
#     484             session_timeout = self._description.logical_session_timeout_minutes
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     203             if timeout == 0 or now > end_time:
#     204                 raise ServerSelectionTimeoutError(
# --> 205                     self._error_message(selector))
#     206
#     207             self._ensure_opened()
#
# ServerSelectionTimeoutError: cluster0-shard-00-01-rnyqh.mongodb.net:27017: [Errno 8] nodename nor servname provided, or not known,cluster0-shard-00-02-rnyqh.mongodb.net:27017: [Errno 8] nodename nor servname provided, or not known,cluster0-shard-00-00-rnyqh.mongodb.net:27017: [Errno 8] nodename nor servname provided, or not known

# %%
preprocess_sentence(recontruct_sentence(df.iloc[2851].sentence,5),2)
# Out:
# [{'word': 'Presne', 'meta': '{S}', 'pos': ['D'], 'lemma': ['presne']},
#  {'word': '.', 'meta': '{/S}', 'pos': [], 'lemma': [None]},
#  {'word': 'Ty', 'meta': '{S}', 'pos': ['P'], 'lemma': ['ty']},
#  {'word': 'nápisy', 'pos': ['S'], 'lemma': ['nápis']},
#  {'word': 'jsou', 'lemma': ['?']},
#  {'word': 'des', 'lemma': ['?']},
#  {'word': '.', 'meta': '{/S}', 'pos': [], 'lemma': [None]},
#  {'word': 'Jako', 'meta': '{S}', 'lemma': ['?']},
#  {'word': 'dárek', 'lemma': ['?']},
#  {'word': 'pro', 'lemma': ['?']},
#  {'word': 'někoho', 'lemma': ['?']},
#  {'word': 'z', 'pos': ['E'], 'lemma': ['z']},
#  {'word': 'ČR', 'pos': [], 'lemma': ['ČR']},
#  {'word': 'určíte', 'pos': ['V'], 'lemma': ['určiť']},
#  {'word': 'ne', 'pos': ['P'], 'lemma': ['ono']},
#  {'word': '-', 'pos': [], 'lemma': [None]},
#  {'word': 'e', 'lemma': ['?']}]

# %%
for sentence in df.iloc[2850:2860]:
    print(transform(sentence))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-61c640c47d8c> in <module>
#       1 for sentence in df.iloc[2850:2860]:
# ----> 2     print(transform(sentence))
#
# NameError: name 'transform' is not defined

# %%
ids == [ c['_id'] for c in db.comments.find().sort('_id',-1).limit(80) ]
# Out:
# True

# %%
db.comments.delete_many({'_id':{'$in':ids}})

# %%
df.iloc[2592]
# Out:
# sentence    Přesně tak, take souhlasím.
# class                 Offer of products
# Name: 2836, dtype: object

# %% [markdown]
# # Banks

# %%
banks
# Out:
#                      class                                           sentence  \
# 0                  Neutral                                                155
# 1                  Neutral                                                NaN
# 2                    Súťaž                              Vsetci tak ze A B C D
# 3                    Súťaž                                Všetci 😃 inak typ B
# 4                    Súťaž                            A, B, C, D takže všetci
# 5                    Súťaž                           C aj keď každý investuje
# 6                    Súťaž      sutazim o krasnu vyhru  žeby vsetci ? A,B,C,D
# 7                    Súťaž                Investor VÚB je C s veľkým úsmevom.
# 8                    Súťaž               Všetci môžu byť investormi vo VÚB...
# 9                    Súťaž  Každý snich môže byť investor vúb banky tipujem C
# 10                   Súťaž  Investor neviem ale každý z nich je určite pla...
# 11                   Súťaž  Každý môže byť ale najviac sa mi hodí D- príje...
# 12                   Súťaž  Investormi sú, podľa mňa, všetci štyria A B C ...
# 13                   Súťaž     Každý môže byť investor,z obrázku sa mi páči C
# 14                   Súťaž  Investorom sú všetci. Ak majú kúpenú nehnuteľn...
# 15                   Súťaž  Pánovi pod D sa to veľmi nevyplatí ale ABC môž...
# 16                   Súťaž  Tak keďže to môže byť ktokoľvek tak si myslím,...
# 17                   Súťaž  D, ten už v jeho veku možno aj ma čo investova...
# 18                   Súťaž  Bez rozdielov, kazdy kto ma kapital ktory inve...
# 19                   Súťaž     Investor môže byť každý tzn. A aj B aj C aj D.
# 20                   Súťaž        A,b,c,d. Kazdy investoval do niecoho ineho.
# 21                   Súťaž  Každý je investorom ale najviac podľa mňa by t...
# 22                   Súťaž  A, B, C, D investor je každý, či už má hypoték...
# 23                   Súťaž                         Každý jeden z nich.... 👍👍👍
# 24                   Súťaž                Všetci môžu byt s VÚB investormi!!!
# 25                   Súťaž             Všetci štyria, vek nie je prekážkou :)
# 26                   Súťaž                  Investormi sú všetci na obrázku ☺
# 27                   Súťaž                     Vsetci styria - A, B, C aj D 😎
# 28                   Súťaž         Investormi mozu byt vsetci ale tipnem si N
# 29                   Súťaž  Ja si myslím že pani pod písmenom A ..\nAle bu...
# ...                    ...                                                ...
# 1290      Ponuka produktov  Presne tak. Načo je mi taká banka keď nevedia ...
# 1291      Ponuka produktov  Jaaj tak Google Pay hej? A Apple Pay nebude? C...
# 1292      Ponuka produktov                             Už dávno malo byť 🍎Pay
# 1293      Ponuka produktov         Apple pay bude cca s prichodom iPhone 15 ?
# 1294      Ponuka produktov                    Davajte uz konecne Apple Pay!!!
# 1295  Problémy s produktom  VÚB banka dobrý deň, opäť mám ten istý problém...
# 1296      Ponuka produktov                            presne si to vystihol 👍
# 1297              Odpovede  Marián Zuzana Lapoš Pekny den. Od jari sme mal...
# 1298      Ponuka produktov  Ste jedna z posledných bank na Slovensku ktorá...
# 1299  Problémy s produktom  Bohumil Bobo Valent presne tak ako vravíš. S m...
# 1300  Problémy s produktom  No ja som tento rok riešila platbu dovolenky, ...
# 1301      Ponuka produktov              Tommy Cé tiez sa radujes z cashbacku?
# 1302      Ponuka produktov                                   Stano Kuruc amen
# 1303      Ponuka produktov  Stano Kuruc Pekny den. Postup nasadzovania bol...
# 1304      Ponuka produktov  Roman, myslim si, ze v dnesnom svete, kedy sa ...
# 1305      Ponuka produktov  ešte aj na ticket restaurant kartu mi to fungu...
# 1306  Problémy s produktom  dnes rovnaky problem, ani cez mobilbanking, an...
# 1307      Ponuka produktov  Podobne, taktiež mi bolo povedané, že najneskô...
# 1308  Problémy s produktom  Presne tak, mám rovnaký problém, ani e-platby ...
# 1309  Problémy s produktom  VÚB banka Rovnaky problem, neda sa nikde prihl...
# 1310      Ponuka produktov  Pridavam sa k ostatnym komentujucim - Apple Pa...
# 1311  Problémy s produktom  Nuz, uz pre istotu ani reakciu nedostaneme. Ra...
# 1312      Ponuka produktov  Za Apple Pay sa tu hádate :) ľudia doteraz bez...
# 1313      Ponuka produktov  Cakanie na  pay od VUB si sprijemnujem s Revo...
# 1314  Problémy s produktom  Rád by som vedel, prečo si nemôžeme ľubovoľne ...
# 1315      Ponuka produktov  VÚB banka dosť zvláštne čo hovoríte nakoľko vo...
# 1316  Problémy s produktom  Ehmm na tento Vas novy typ kodovania do intern...
# 1317  Problémy s produktom  Erika Fúsková Mne to urobiť nechceli. Neriešim...
# 1318      Ponuka produktov  Mrzi ma, ze moja oblubena banka na SK si nedok...
# 1319                 Súťaž                               Každý z nich ABCD :)
#
#       likes  sentiment_percentage  sentiment_class
# 0         0                0.5000                0
# 1         0                0.5000                0
# 2         0                0.5000                0
# 3         0                0.6240                3
# 4         0                0.5000                0
# 5         0                0.4986                2
# 6         0                0.7843                3
# 7         0                0.3979                2
# 8         0                0.4731                2
# 9         0                0.3741                2
# 10        0                0.3113                2
# 11        0                0.4482                2
# 12        0                0.7756                3
# 13        0                0.8176                3
# 14        0                0.1459                2
# 15        0                0.4741                2
# 16        0                0.4163                2
# 17        0                0.5493                3
# 18        0                0.4872                2
# 19        0                0.4869                2
# 20        0                0.5009                3
# 21        0                0.4869                2
# 22        1                0.1367                2
# 23        0                0.5797                3
# 24        0                0.4731                2
# 25        0                0.5654                3
# 26        0                0.5252                3
# 27        0                0.4163                2
# 28        0                0.4869                2
# 29        0                0.6722                3
# ...     ...                   ...              ...
# 1290     37                0.4010                2
# 1291      5                0.0906                2
# 1292      2                0.3616                2
# 1293      5                0.4583                2
# 1294      3                0.5225                3
# 1295      1                0.1623                2
# 1296      7                0.6607                3
# 1297      3                0.0315                2
# 1298     13                0.2645                2
# 1299      0                0.3898                2
# 1300      1                0.4803                2
# 1301      0                0.5000                1
# 1302      0                0.5000                1
# 1303      0                0.2261                2
# 1304      1                0.0187                2
# 1305      2                0.4268                2
# 1306      0                0.4480                2
# 1307      1                0.3177                2
# 1308      0                0.2026                2
# 1309      0                0.3031                2
# 1310      5                0.2548                2
# 1311      0                0.1198                2
# 1312      4                0.4004                2
# 1313      2                0.5714                3
# 1314      2                0.0015                2
# 1315      3                0.1985                2
# 1316      2                0.2127                2
# 1317      1                0.2250                2
# 1318      7                0.2854                2
# 1319      0                0.6388                3
#
# [1320 rows x 5 columns]

# %%
banks.describe(include='all')
# Out:
#         class sentence        likes  sentiment_percentage  sentiment_class
# count    1320     1310  1320.000000           1320.000000      1320.000000
# unique     12      892          NaN                   NaN              NaN
# top     Súťaž        A          NaN                   NaN              NaN
# freq      868       92          NaN                   NaN              NaN
# mean      NaN      NaN     0.328030              0.483195         1.459848
# std       NaN      NaN     1.649997              0.140206         1.186183
# min       NaN      NaN     0.000000              0.001500         0.000000
# 25%       NaN      NaN     0.000000              0.468900         0.000000
# 50%       NaN      NaN     0.000000              0.500000         2.000000
# 75%       NaN      NaN     0.000000              0.500000         2.000000
# max       NaN      NaN    37.000000              0.969100         3.000000

# %%
banks['class'] = banks['class'].apply(lambda x: 'Problémy s produktom' if x == 'Problémy s produktov' else  x)

# %%
recontruct_sentence(banks.iloc[0].sentence, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1ea4a99b38f8> in <module>
# ----> 1 recontruct_sentence(banks.iloc[0].sentence, 0)
#
# NameError: name 'recontruct_sentence' is not defined
