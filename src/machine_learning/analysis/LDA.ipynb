# %%
import pandas as pd
import numpy as np
from time import sleep
import re
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from functools import reduce
import requests
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
banks = pd.read_csv('./data/banks.csv', names=['class','sentence', 'likes', 'sentiment_percentage', 'sentiment_class', 'post_id', 'posted_by_bank'])
banks = banks[ ~(banks.isnull().sentence == True)].drop_duplicates('sentence')

# %%
banks[1].sentence
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-bc71a117a5cb> in <module>
# ----> 1 banks[1].sentence
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
slovak_stopwords = ['a',
 'aby',
 'aj',
 'ak',
 'ako',
 'ale',
 'alebo',
 'and',
 'ani',
 'áno',
 'asi',
 'až',
 'bez',
 'bude',
 'budem',
 'budeš',
 'budeme',
 'budete',
 'budú',
 'by',
 'bol',
 'bola',
 'boli',
 'bolo',
 'byť',
 'cez',
 'čo',
 'či',
 'ďalší',
 'ďalšia',
 'ďalšie',
 'dnes',
 'do',
 'ho',
 'ešte',
 'for',
 'i',
 'ja',
 'je',
 'jeho',
 'jej',
 'ich',
 'iba',
 'iné',
 'iný',
 'som',
 'si',
 'sme',
 'sú',
 'k',
 'kam',
 'každý',
 'každá',
 'každé',
 'každí',
 'kde',
 'keď',
 'kto',
 'ktorá',
 'ktoré',
 'ktorou',
 'ktorý',
 'ktorí',
 'ku',
 'lebo',
 'len',
 'ma',
 'mať',
 'má',
 'máte',
 'medzi',
 'mi',
 'mna',
 'mne',
 'mnou',
 'musieť',
 'môcť',
 'môj',
 'môže',
 'my',
 'na',
 'nad',
 'nám',
 'náš',
 'naši',
 'nie',
 'nech',
 'než',
 'nič',
 'niektorý',
 'nové',
 'nový',
 'nová',
 'nové',
 'noví',
 'o',
 'od',
 'odo',
 'of',
 'on',
 'ona',
 'ono',
 'oni',
 'ony',
 'po',
 'pod',
 'podľa',
 'pokiaľ',
 'potom',
 'práve',
 'pre',
 'prečo',
 'preto',
 'pretože',
 'prvý',
 'prvá',
 'prvé',
 'prví',
 'pred',
 'predo',
 'pri',
 'pýta',
 's',
 'sa',
 'so',
 'si',
 'svoje',
 'svoj',
 'svojich',
 'svojím',
 'svojími',
 'ta',
 'tak',
 'takže',
 'táto',
 'teda',
 'te',
 'tě',
 'ten',
 'tento',
 'the',
 'tieto',
 'tým',
 'týmto',
 'tiež',
 'to',
 'toto',
 'toho',
 'tohoto',
 'tom',
 'tomto',
 'tomuto',
 'toto',
 'tu',
 'tú',
 'túto',
 'tvoj',
 'ty',
 'tvojími',
 'už',
 'v',
 'vám',
 'váš',
 'vaše',
 'vo',
 'viac',
 'však',
 'všetok',
 'vy',
 'z',
 'za',
 'zo',
 'že']

# %%
cv = CountVectorizer(stop_words=slovak_stopwords)

# %%
dtm = cv.fit_transform(banks['sentence'])

# %%
dtm
# Out:
# <890x3647 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8117 stored elements in Compressed Sparse Row format>

# %%
LDA = LatentDirichletAllocation(n_components=5,random_state=42)

# %%
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=5, n_jobs=None,
#                           perp_tol=0.1, random_state=42, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
cv.get_feature_names()
# Out:
# ['00',
#  '000',
#  '01',
#  '0185aec9cc53783197af1ced89e9e790',
#  '0910',
#  '10',
#  '100',
#  '1000',
#  '100petcent',
#  '10k',
#  '10plus',
#  '11',
#  '1100',
#  '12',
#  '12m',
#  '13',
#  '13dni',
#  '14',
#  '15',
#  '150',
#  '155',
#  '18',
#  '1mesiac',
#  '1nou',
#  '1x',
#  '20',
#  '2018',
#  '2019',
#  '2021',
#  '2022',
#  '20k',
#  '24',
#  '2500',
#  '27',
#  '2x',
#  '30',
#  '300',
#  '32',
#  '327',
#  '33',
#  '333',
#  '335',
#  '339',
#  '350',
#  '362',
#  '365',
#  '38',
#  '3d',
#  '3pp',
#  '3x',
#  '42',
#  '49',
#  '50',
#  '513',
#  '550',
#  '62',
#  '676',
#  '68',
#  '6boxov',
#  '738',
#  '75',
#  '775',
#  '7x',
#  '900',
#  '927',
#  '98',
#  'a10',
#  'a6',
#  'abc',
#  'abcd',
#  'abn',
#  'absolutne',
#  'absolútne',
#  'absurdná',
#  'ach',
#  'adrese',
#  'adresu',
#  'adresy',
#  'adries',
#  'agenda',
#  'agenturu',
#  'ahojte',
#  'ajpreto',
#  'akceptované',
#  'ake',
#  'akejkoľvek',
#  'akoby',
#  'akonáhle',
#  'akou',
#  'akoze',
#  'akože',
#  'aksagav',
#  'aktivoval',
#  'aktivovane',
#  'aktivované',
#  'aktiváciu',
#  'aktivít',
#  'aktualizacie',
#  'aktualizacii',
#  'aktualizaciou',
#  'aktualizaciu',
#  'aktualizcii',
#  'aktualizoval',
#  'aktualizované',
#  'aktualizovať',
#  'aktualizácia',
#  'aktualizáciach',
#  'aktualizácie',
#  'aktualizácii',
#  'aktualizáciou',
#  'aktualizáciu',
#  'aktuálna',
#  'aktuálne',
#  'aktívne',
#  'akuálne',
#  'akvizičnej',
#  'aky',
#  'aké',
#  'akékoľvek',
#  'aký',
#  'albi',
#  'aleb',
#  'alexander',
#  'alrbo',
#  'alternatívou',
#  'alternatívu',
#  'amen',
#  'amro',
#  'andrea',
#  'android',
#  'androide',
#  'androidom',
#  'androidu',
#  'anglicku',
#  'anicka',
#  'anj',
#  'ankete',
#  'ano',
#  'ap',
#  'apk',
#  'apka',
#  'apke',
#  'apku',
#  'apky',
#  'aplikacia',
#  'aplikacie',
#  'aplikacii',
#  'aplikaciu',
#  'aplikácia',
#  'aplikácie',
#  'aplikácii',
#  'aplikáciu',
#  'aplikácií',
#  'appiek',
#  'appka',
#  'appke',
#  'appkou',
#  'appku',
#  'appky',
#  'apple',
#  'applepay',
#  'applisti',
#  'applu',
#  'argumentácia',
#  'arpas',
#  'aspon',
#  'aspoň',
#  'atm',
#  'atomu',
#  'atp',
#  'atď',
#  'august',
#  'auparku',
#  'auta',
#  'automaty',
#  'autorizáciu',
#  'avizovali',
#  'avsak',
#  'avšak',
#  'az',
#  'babenka',
#  'bajviac',
#  'bali',
#  'balik',
#  'balki',
#  'balík',
#  'balíku',
#  'bambusmi',
#  'bank',
#  'banka',
#  'bankami',
#  'bankar',
#  'banke',
#  'banking',
#  'bankingu',
#  'bankomat',
#  'bankomate',
#  'bankomatmi',
#  'bankomatoch',
#  'bankomatov',
#  'bankomatu',
#  'bankomaty',
#  'bankou',
#  'bankoviek',
#  'bankovnictvo',
#  'bankovníctvo',
#  'banku',
#  'banky',
#  'bankár',
#  'bankára',
#  'bannery',
#  'banska',
#  'banskej',
#  'bavime',
#  'baška',
#  'bc',
#  'bedecs',
#  'benefitný',
#  'benkeová',
#  'beriem',
#  'berkešová',
#  'beta',
#  'bezhlavo',
#  'bezia',
#  'bezkonkurencna',
#  'bezkontaktne',
#  'bezkontaktné',
#  'bezne',
#  'bezny',
#  'bezpecnosti',
#  'bezpecnostne',
#  'bezpečnosť',
#  'bezpečnosťou',
#  'bezpečnú',
#  'bezplatnej',
#  'bezplatnom',
#  'bezplatnú',
#  'bezplatný',
#  'beztak',
#  'bezucelovy',
#  'bežec',
#  'bežného',
#  'bežných',
#  'bim',
#  'bit',
#  'blabotala',
#  'blahozelam',
#  'blbca',
#  'blbe',
#  'blichová',
#  'blikajucej',
#  'bližšie',
#  'blázníte',
#  'blízkej',
#  'bobo',
#  'bodnár',
#  'bodvou',
#  'bohumil',
#  'bohuzial',
#  'bohužiaľ',
#  'bolešová',
#  'bonusy',
#  'boris',
#  'bory',
#  'bostone',
#  'bota',
#  'bože',
#  'bral',
#  'brand',
#  'bravooo',
#  'brať',
#  'browser',
#  'btw',
#  'budiš',
#  'budu',
#  'buducna',
#  'budúce',
#  'budúcna',
#  'budúcnosti',
#  'burze',
#  'business',
#  'buď',
#  'bystrica',
#  'bystrici',
#  'byt',
#  'bytosti',
#  'bytu',
#  'bánk',
#  'caka',
#  'cakanie',
#  'cakat',
#  'card',
#  'cas',
#  'cashback',
#  'cashbacku',
#  'casovo',
#  'casto',
#  'cca',
#  'ccc',
#  'celeho',
#  'celkom',
#  'celkovo',
#  'celkové',
#  'celom',
#  'celoročne',
#  'cely',
#  'celé',
#  'celý',
#  'cent',
#  'centov',
#  'centrálnej',
#  'cery93',
#  'ces',
#  'ceste',
#  'cesto',
#  'cestovné',
#  'cgkx4azge4qgs',
#  'chapem',
#  'chat',
#  'chatrnuch',
#  'chce',
#  'chcel',
#  'chcelo',
#  'chcem',
#  'chceme',
#  'chcete',
#  'chcieť',
#  'chcu',
#  'chcú',
#  'chlapa',
#  'chodia',
#  'chodili',
#  'chodit',
#  'chodí',
#  'chorej',
#  'chorvatov',
#  'chorvatsku',
#  'chorvátsku',
#  'chvalite',
#  'chváli',
#  'chválim',
#  'chvíli',
#  'chvíľu',
#  'chyba',
#  'chybe',
#  'chybu',
#  'chyby',
#  'chystáme',
#  'chápať',
#  'chápem',
#  'ci',
#  'cim',
#  'cislach',
#  'cislo',
#  'citlivo',
#  'cize',
#  'clankom',
#  'clanok',
#  'clearka',
#  'clenovia',
#  'clovek',
#  'cloveku',
#  'clues',
#  'co',
#  'com',
#  'cudoval',
#  'cudzej',
#  'cudzou',
#  'cz',
#  'cé',
#  'cítili',
#  'da',
#  'dajte',
#  'daju',
#  'dake',
#  'dakujem',
#  'dakujeme',
#  'dala',
#  'dali',
#  'dalo',
#  'dalsie',
#  'dalsiu',
#  'danej',
#  'daniel',
#  'daniela',
#  'danom',
#  'daného',
#  'darcekov',
#  'dat',
#  'databázy',
#  'datumov',
#  'dava',
#  'davajte',
#  'davno',
#  'dať',
#  'dds',
#  'deaktivovali',
#  'dealovat',
#  'debetné',
#  'decembra',
#  'definujú',
#  'deje',
#  'deklarované',
#  'den',
#  'denis',
#  'denný',
#  'depresivnejsiu',
#  'deti',
#  'deň',
#  'dialnica',
#  'dialog',
#  'dialogu',
#  'dialógu',
#  'diela',
#  'digital',
#  'digitalizacie',
#  'digitálna',
#  'digitálneho',
#  'digitálnej',
#  'dik',
#  'dikes',
#  'diky',
#  'diskomfort',
#  'diskusiu',
#  'disponent',
#  'dispozícii',
#  'divné',
#  'dizajn',
#  'dizajnovo',
#  'dizajny',
#  'dlhej',
#  'dlhi',
#  'dlho',
#  'dlhodobo',
#  'dlhoročné',
#  'dlhoročným',
#  'dlhé',
#  'dnesnom',
#  'dnešnej',
#  'dni',
#  'dní',
#  'dobe',
#  'dobeho',
#  'dobre',
#  'dobri',
#  'dobroprajna',
#  'dobry',
#  'dobrá',
#  'dobré',
#  'dobrý',
#  'dobrých',
#  'dobu',
#  'doby',
#  'dochodca',
#  'dochodcom',
#  'dochodok',
#  'dockame',
#  'dodať',
#  'dodržal',
#  'dodá',
#  'dodávateľ',
#  'dodávateľa',
#  'dohodnite',
#  'dohodnutie',
#  'dohromady',
#  'doj',
#  'dojmami',
#  'dojne',
#  'dokedy',
#  'dokonca',
#  'dokopy',
#  'dokumentu',
#  'dokážeme',
#  'dolami',
#  'dolnej',
#  'dolárovým',
#  'dom',
#  'dominik',
#  'domovskej',
#  'domu',
#  'don',
#  'donedávna',
#  'dookola',
#  'doplatit',
#  'dopytovat',
#  'dopísať',
#  'doraz',
#  'doriesit',
#  'doriešená',
#  'doslova',
#  'dostal',
#  'dostali',
#  'dostať',
#  'dostupna',
#  'dostupnych',
#  'dostupné',
#  'dostávali',
#  'dosť',
#  'doterajšie',
#  'doterajšiu',
#  'doteraz',
#  'dotiahnuť',
#  'dotycny',
#  'dotyčný',
#  'dovod',
#  'dovolat',
#  'dovolenky',
#  'dozadu',
#  'dozviete',
#  'dočkáme',
#  'draho',
#  'drahocenny',
#  'drahý',
#  'drahšie',
#  'drahší',
#  'drobcov',
#  'druh',
#  'druha',
#  'druhom',
#  'druhá',
#  'drvivú',
#  'dráha',
#  'držať',
#  'držiteľa',
#  'držím',
#  'dss',
#  'dufam',
#  'dujú',
#  'duplicitné',
#  'dusickoveho',
#  'dusickovy',
#  'dutko',
#  'dušan',
#  'dušičkový',
#  'dušu',
#  'dva',
#  'dve',
#  'dvihnut',
#  'dvoch',
#  'dvojitú',
#  'dvojitým',
#  'dvoma',
#  'dá',
#  'dám',
#  'dáma',
#  'dáte',
#  'dátum',
#  'dáva',
#  'dávajú',
#  'dávam',
#  'dávid',
#  'dávnejšie',
#  'dávno',
#  'dç',
#  'dôchodca',
#  'dôchodkovom',
#  'dôležité',
#  'dôsledkom',
#  'dôvera',
#  'dôveru',
#  'dôvod',
#  'dôvodom',
#  'dôvodov',
#  'dôvodu',
#  'dúfam',
#  'dĺho',
#  'dňa',
#  'dňoch',
#  'džadooň',
#  'ecb',
#  'efektivita',
#  'ehmm',
#  'electron',
#  'email',
#  'emailovej',
#  'erich',
#  'erik',
#  'erika',
#  'este',
#  'eur',
#  'europa',
#  'europy',
#  'evidujeme',
#  'exekutota',
#  'existovať',
#  'expresne',
#  'face',
#  'facebook',
#  'facebooku',
#  'fajn',
#  'fakt',
#  'faktora',
#  'faktury',
#  'fandíme',
#  'farbou',
#  'fascinujúce',
#  'fb',
#  'final',
#  'finale',
#  'financii',
#  'finanční',
#  'finito',
#  'fintech',
#  'firemna',
#  'firemne',
#  'firemneho',
#  'firemnej',
#  'firemnou',
#  'firemné',
#  'firemných',
#  'fischer',
#  'fischo',
#  'flash',
#  'fondy',
#  'fonom',
#  'formou',
#  'formulara',
#  'fortuna',
#  'foto',
#  'ft',
#  'funckionality',
#  'fungoval',
#  'fungovali',
#  'fungovalo',
#  'fungovaním',
#  'fungovat',
#  'fungovať',
#  'funguje',
#  'fungujú',
#  'fungujúcim',
#  'funkcia',
#  'funkcie',
#  'funkcii',
#  'funkcionality',
#  'funkciu',
#  'funkcna',
#  'funkcnosti',
#  'funkcnu',
#  'funkovali',
#  'funkčnosť',
#  'funkčné',
#  'funuse',
#  'furt',
#  'fuuu',
#  'fúsková',
#  'gabriel',
#  'gabriela',
#  'galaxy',
#  'garmin',
#  'garminpay',
#  'gastrolískovej',
#  'gelefonu',
#  'gerhard',
#  'gilan',
#  'globálne',
#  'gm',
#  'gmail',
#  'google',
#  'googlepay',
#  'gp',
#  'gpay',
#  'gratulujem',
#  'gratuláciu',
#  'guy',
#  'hadam',
#  'haji',
#  'hana',
#  'hanbit',
#  'hanbite',
#  'happy',
#  'hej',
#  'helga',
#  'helpdesk',
#  'hentom',
#  'hladiska',
#  'hlasene',
#  'hlavičkou',
#  'hlavne',
#  'hlavnu',
#  'hlavných',
#  'hlavným',
#  'hlavu',
#  'hlavy',
#  'hlboko',
#  'hlásenie',
#  'hlásiť',
#  'hm',
#  'hmmm',
#  'hmmmm',
#  'hned',
#  'hneď',
#  'hocikto',
#  'hodi',
#  'hodine',
#  'hodinkami',
#  'hodinky',
#  'hodiny',
#  'hodinách',
#  'hodne',
#  'hodnotenia',
#  'hodnotenie',
#  'hodí',
#  'hodín',
#  'hodî',
#  'holandsku',
#  'homebutton',
#  'horami',
#  'hore',
#  'horizonte',
#  'horsie',
#  'horská',
#  'horvath',
#  'horšie',
#  'hotova',
#  'hotovosti',
#  'hotovostné',
#  'hotovosť',
#  'hovancova',
#  'hovorí',
#  'hovoríte',
#  'hrabať',
#  'hrdí',
#  'hrdý',
#  'hrozne',
#  'hrôza',
#  'https',
#  'hudák',
#  'hupcej',
#  'huraaa',
#  'hviezdou',
#  'hypoteku',
#  'hypotekárni',
#  'hypotekárnom',
#  'hypotéku',
#  'hádam',
#  'hádate',
#  'ib',
#  'ibanu',
#  'ibe',
#  'id',
#  'ide',
#  'identifikovali',
#  'identifikuje',
#  'identifikáciu',
#  'idiot',
#  'idu',
#  'ifortuna',
#  'ignorantsky',
#  'ignoruje',
#  'ignorujete',
#  'ilushak',
#  'ilúzie',
#  'im',
#  'imho',
#  'implementovat',
#  'implementujeme',
#  'inac',
#  'inak',
#  'inam',
#  'inde',
#  'individ',
#  'individualne',
#  'individuálny',
#  'ine',
#  'ineho',
#  'inej',
#  'info',
#  'informovali',
#  'informovať',
#  'informácia',
#  'informácie',
#  'informáciu',
#  'ing',
#  'inou',
#  'inovacia',
#  'inovacii',
#  'inovaciu',
#  'inovativne',
#  'inovatívne',
#  'inovovať',
#  'inováciami',
#  'inovácie',
#  'inováciám',
#  'inovácií',
#  'instantné',
#  'instantných',
#  'intenzite',
#  'intenzitu',
#  'intenzívne',
#  'internet',
#  'internetbanking',
#  'internete',
#  'intesa',
#  'investicii',
#  'investičné',
#  'investor',
#  'investori',
#  'investorka',
#  'investormi',
#  'investormy',
#  'investorom',
#  'investory',
#  'investoval',
#  'investovala',
#  'investovali',
#  'investovania',
#  'investovanie',
#  'investovat',
#  'investovať',
#  'investuje',
#  'investujeme',
#  'investície',
#  'investíciou',
#  'invrstorom',
#  'iny',
#  'inymi',
#  'iná',
#  'ináč',
#  'iného',
#  'inú',
#  'iných',
#  'iným',
#  'inštalácia',
#  'inštaláciou',
#  'inštaláciu',
#  'inštitúcie',
#  'ios',
#  'ip',
#  'iphone',
#  'isli',
#  'ist',
#  'ista',
#  'iste',
#  'isto',
#  'istota',
#  'istotu',
#  'isté',
#  'istý',
#  'istým',
#  'it',
#  'ivan',
#  'ivasuk',
#  'ivestorka',
#  'ivulko',
#  'išlo',
#  'jaaj',
#  'jablkami',
#  'jaj',
#  'jak',
#  'jakub',
#  'jan',
#  'jari',
#  'jasne',
#  'jasného',
#  'jeden',
#  'jedinca',
#  'jedine',
#  'jediného',
#  'jediný',
#  'jedlo',
#  'jedna',
#  'jedneho',
#  'jednej',
#  'jedno',
#  'jednoducha',
#  'jednoducho',
#  'jednoduché',
#  'jednorazovo',
#  'jednorazového',
#  'jednorázovo',
#  'jednotlivé',
#  'jednoznacne',
#  'jednoznačne',
#  'jednu',
#  'jedná',
#  'jedného',
#  'jednému',
#  'jemnej',
#  'jj',
#  'jozef',
#  'jozefino',
#  'ju',
#  'jul',
#  'juraj',
#  'já',
#  'ján',
#  'július',
#  'kalkulačka',
#  'kalkulačku',
#  'kamil',
#  'kampane',
#  'kanaly',
#  'kapital',
#  'karel',
#  'kariet',
#  'karta',
#  'kartami',
#  'karte',
#  'kartou',
#  'kartovy',
#  'kartový',
#  'kartu',
#  'karty',
#  'katarína',
#  'katastrofa',
#  'katka',
#  'kazdej',
#  'kazdemu',
#  'kazdou',
#  'kazdy',
#  'kazdya',
#  'každej',
#  'každi',
#  'každom',
#  'každopádne',
#  'každy',
#  'každého',
#  'každému',
#  'každú',
#  'ke',
#  'keby',
#  'ked',
#  'kedy',
#  'kedysi',
#  'kedze',
#  'kef',
#  'kekláková',
#  'key',
#  'keďže',
#  'kind',
#  'kindji',
#  'klamari',
#  'klasickom',
#  'klasickú',
#  'klebety',
#  'klient',
#  'klienti',
#  'klientom',
#  'klientov',
#  'klikal',
#  'kliknutí',
#  'kludne',
#  'kockateho',
#  'kod',
#  'kodovania',
#  'koho',
#  'kolega',
#  'kolegami',
#  'kolegom',
#  'kolegov',
#  'kolegovi',
#  'kolegovia',
#  'koli',
#  'kolko',
#  'kolvek',
#  'komentare',
#  'komentoch',
#  'komentujucim',
#  'komentujúci',
#  'komplexnejší',
#  'komplikácie',
#  'komu',
#  'komunikujeme',
#  'komunikácie',
#  'komunistov',
#  'konca',
#  'konci',
#  'konecne',
#  'konečne',
#  'konkretizovať',
#  'konkrétne',
#  'konkrétnej',
#  'konkrétnu',
#  'konkrétny',
#  'konkurenciu',
#  'konkurenti',
#  'kontakt',
#  'kontaktnej',
#  'kontaktných',
#  'kontaktoval',
#  'kontaktovat',
#  'kontaktovať',
#  'kontaktujte',
#  'kontinenty',
#  'kontrolka',
#  'končím',
#  'konštantný',
#  'kopa',
#  'kopec',
#  'kosic',
#  'kotlar',
#  'kotora',
#  'kovács',
#  'kováč',
#  'koze',
#  'koľko',
#  'kradnú',
#  'krajčík',
#  'krajšie',
#  'krasa',
#  ...]

# %%
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([cv.get_feature_names()[i] for i in topic.argsort()[-15:]])
    print('\n')
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['mozu', 'tipujem', 'su', 'abcd', 'myslím', 'investormi', 'môžu', 'vúb', 'investori', 'nich', 'byt', 'investorom', 'vsetci', 'investor', 'všetci']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['problém', 'keďže', 'treba', 'dá', '30', 'dobrý', 'limit', 'tb', 'mám', 'apple', 'ze', 'deň', 'pay', 'tatra', 'banka']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['aplikácie', '10', 'aktuálne', 'ste', 'nás', 'google', 'platby', 'ďakujeme', 'dobrý', 'tatra', 'banka', 'pay', 'pekný', 'prajeme', 'deň']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['peter', 'tam', 'google', 'ze', 'tb', 'mňa', 'super', 'moze', 'ste', 'tatra', 'apple', 'jeden', 'banka', 'kazdy', 'pay']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['klientom', 'vas', 'ked', 'zaoberáme', 'dobrý', 'myslim', 'veríme', 'pay', 'riešenie', 'banka', 'apple', 'pekný', 'prajeme', 'deň', 'ze']

# %%
topic_results = LDA.transform(dtm)

# %%
banks['Topic'] = topic_results.argmax(axis=1)

# %%
banks[['class', 'Topic']].corr()
# Out:
#        Topic
# Topic    1.0

# %%
banks[['Topic','class', 'sentence']].groupby(['Topic','class']).count()
# Out:
#                                  sentence
# Topic class
# 0     Cena produktov / benefity         6
#       Interakcia                       19
#       Neutral                           9
#       Odpovede                         56
#       Otázky                            6
#       Ponuka produktov                  9
#       Problémy s produktom              5
#       Problémy s produktov             15
#       Produkt                           1
#       Súťaž                           109
# 1     Cena produktov / benefity         4
#       Interakcia                        8
#       Neutral                          14
#       Ostatné                           3
#       Otázky                            3
#       Pobočka                           2
#       Ponuka produktov                 26
#       Problémy s produktom              1
#       Problémy s produktov             22
#       Produkt                           9
#       Súťaž                           118
# 2     Cena produktov / benefity         5
#       Interakcia                       11
#       Neutral                          16
#       Odpovede                          1
#       Ostatné                           1
#       Otázky                            5
#       Pobočka                           1
#       Ponuka produktov                  7
#       Problémy s produktom              3
#       Problémy s produktov             23
#       Produkt                          10
#       Súťaž                            70
# 3     Cena produktov / benefity         6
#       Interakcia                        3
#       Neutral                          14
#       Odpovede                          5
#       Ostatné                           2
#       Otázky                            5
#       Ponuka produktov                  3
#       Problémy s produktom              1
#       Problémy s produktov             10
#       Produkt                           5
#       Súťaž                           137
# 4     Cena produktov / benefity         8
#       Interakcia                        6
#       Neutral                          19
#       Odpovede                         20
#       Ostatné                           1
#       Otázky                            1
#       Pobočka                           1
#       Ponuka produktov                 16
#       Problémy s produktov             13
#       Produkt                           1
#       Súťaž                            15
